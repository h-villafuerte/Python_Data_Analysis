# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **¡Netflix**! Lo que comenzó en 1997 como un servicio de alquiler de DVD se ha convertido desde entonces en una de las empresas de medios y entretenimiento más grandes.
#
# Dada la gran cantidad de películas y series disponibles en la plataforma, es una oportunidad perfecta para ejercitar sus habilidades de análisis de datos exploratorios y sumergirse en la industria del entretenimiento. Nuestro amigo también ha estado repasando sus habilidades con Python y ha probado por primera vez un archivo CSV que contiene datos de Netflix. Creen que la duración media de las películas ha ido disminuyendo. Utilizando la investigación inicial de tus amigos, profundizarás en los datos de Netflix para ver si puedes determinar si la duración de las películas en realidad se está acortando y explicar algunos de los factores que contribuyen, si los hay.
#
# Se le ha proporcionado el conjunto de datos `netflix_data.csv`, junto con la siguiente tabla que detalla los nombres y descripciones de las columnas:
#
# ## Los datos
# ### **netflix_data.csv**
# | Columna | Descripción |
# |--------|-------------|
# | `mostrar_id` | El ID del espectáculo |
# | `tipo` | Tipo de espectáculo |
# | `título` | Título del espectáculo |
# | `director` | Director del espectáculo |
# | `reparto` | Elenco del programa |
# | `país` | País de origen |
# | `fecha_agregada` | Fecha agregada a Netflix |
# | `año_lanzamiento` | Año de lanzamiento de Netflix |
# | `duración` | Duración del espectáculo en minutos |
# | `descripción` | Descripción del espectáculo |
# | `género` | Mostrar género |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# - Cargue el archivo CSV y guárdelo como netflix_df.
netflix_df = pd.read_csv("netflix_data.csv")

# - Filtre los datos para eliminar programas de TV y almacenarlos como netflix_subset.
# netflix_df["type"].unique().tolist()
netflix_subset = netflix_df[netflix_df['type']!="TV Show"]
# netflix_subset
# - Investigue los datos de las películas de Netflix, manteniendo solo las columnas "título", "país", "género", "año_estreno", "duración" y guárdelas en un nuevo DataFrame llamado netflix_movies.
# Out:
#      show_id   type                                    title
# 1         s2  Movie                                     7:19  \
# 2         s3  Movie                                    23:59
# 3         s4  Movie                                        9
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# ...      ...    ...                                      ...
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7783   s7784  Movie                                   Zubaan
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  \
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# ...
